# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/IP/Project/jsbach_chorals_harmony.data')

# %%
data
# Out:
#      Choral ID  Event number    C C#/Db    D D#/Eb    E    F F#/Gb    G G#/Ab  \
# 0     000106b_             1  YES    NO   NO    NO   NO  YES    NO   NO    NO
# 1     000106b_             2  YES    NO   NO    NO  YES   NO    NO  YES    NO
# 2     000106b_             3  YES    NO   NO    NO  YES   NO    NO  YES    NO
# 3     000106b_             4  YES    NO   NO    NO   NO  YES    NO   NO    NO
# 4     000106b_             5  YES    NO   NO    NO   NO  YES    NO   NO    NO
# ...        ...           ...  ...   ...  ...   ...  ...  ...   ...  ...   ...
# 5660  015505b_           105   NO    NO  YES    NO   NO   NO    NO  YES    NO
# 5661  015505b_           106   NO    NO  YES    NO   NO   NO    NO  YES    NO
# 5662  015505b_           107  YES    NO   NO    NO  YES   NO    NO  YES    NO
# 5663  015505b_           108  YES    NO   NO    NO  YES   NO    NO  YES    NO
# 5664  015505b_           109   NO    NO   NO    NO   NO  YES    NO   NO    NO
#
#         A A#/Bb   B Bass  Meter Chord label
# 0     YES    NO  NO    F      3         F_M
# 1      NO    NO  NO    E      5         C_M
# 2      NO    NO  NO    E      2         C_M
# 3     YES    NO  NO    F      3         F_M
# 4     YES    NO  NO    F      2         F_M
# ...   ...   ...  ..  ...    ...         ...
# 5660   NO   YES  NO    G      4         G_m
# 5661  YES    NO  NO    G      3         G_m
# 5662   NO    NO  NO    C      5         C_M
# 5663   NO   YES  NO    C      3         C_M
# 5664  YES    NO  NO    F      4         F_M
#
# [5665 rows x 17 columns]

# %%
Y = data['Chord label']
Y
# Out:
# 0       F_M
# 1       C_M
# 2       C_M
# 3       F_M
# 4       F_M
#        ...
# 5660    G_m
# 5661    G_m
# 5662    C_M
# 5663    C_M
# 5664    F_M
# Name: Chord label, Length: 5665, dtype: object

# %%
Y.shape
# Out:
# (5665,)

# %%
Y.unique()
# Out:
# array(['F_M', 'C_M', 'D_m', 'BbM', 'C_M7', 'D_m7', 'G_M', 'A_m', 'C_M4',
#        'G_m', 'G_M7', 'D_M', 'F#d', 'AbM', 'C#d7', 'D_M7', 'A_M', 'EbM',
#        'F_M7', 'C_m', 'A_M4', 'F#m', 'B_M', 'E_M', 'D#d', 'C#M', 'F#m7',
#        'A#d', 'B_m', 'E_M7', 'E_m', 'F#M', 'F#M7', 'B_M7', 'A_m6', 'C#d',
#        'A_m7', 'A_d', 'C_m7', 'G_m6', 'D_M4', 'G_m7', 'E_m7', 'E_m6',
#        'A_M7', 'C#m', 'C#M7', 'A#d7', 'EbM7', 'B_m7', 'E_M4', 'C#m7',
#        'F_M4', 'D_m6', 'G#d', 'G#d7', 'A_m4', 'D_M6', 'F_d', 'B_m6',
#        'B_M4', 'C_m6', 'F_m', 'G_M4', 'F_m7', 'C_d6', 'F_m6', 'G_M6',
#        'A_M6', 'F_M6', 'F#M4', 'B_d7', 'D_d7', 'E_d', 'Bbm', 'Bbm6',
#        'DbM', 'C_d7', 'F#d7', 'Abd', 'Ebd', 'Dbd7', 'Dbd', 'Bbd', 'Dbm7',
#        'Abm', 'DbM7', 'Dbm', 'F#m6', 'G#m', 'B_d', 'C_M6', 'D#m', 'D#M',
#        'BbM7', 'F_d7', 'C#d6', 'G_d', 'G#M', 'C#M4', 'D#d6', 'D#d7'],
#       dtype=object)

# %%
X = data.drop(['Chord label', 'Choral ID', 'Event number'], axis = 1)
X
# Out:
#         C C#/Db    D D#/Eb    E    F F#/Gb    G G#/Ab    A A#/Bb   B Bass  \
# 0     YES    NO   NO    NO   NO  YES    NO   NO    NO  YES    NO  NO    F
# 1     YES    NO   NO    NO  YES   NO    NO  YES    NO   NO    NO  NO    E
# 2     YES    NO   NO    NO  YES   NO    NO  YES    NO   NO    NO  NO    E
# 3     YES    NO   NO    NO   NO  YES    NO   NO    NO  YES    NO  NO    F
# 4     YES    NO   NO    NO   NO  YES    NO   NO    NO  YES    NO  NO    F
# ...   ...   ...  ...   ...  ...  ...   ...  ...   ...  ...   ...  ..  ...
# 5660   NO    NO  YES    NO   NO   NO    NO  YES    NO   NO   YES  NO    G
# 5661   NO    NO  YES    NO   NO   NO    NO  YES    NO  YES    NO  NO    G
# 5662  YES    NO   NO    NO  YES   NO    NO  YES    NO   NO    NO  NO    C
# 5663  YES    NO   NO    NO  YES   NO    NO  YES    NO   NO   YES  NO    C
# 5664   NO    NO   NO    NO   NO  YES    NO   NO    NO  YES    NO  NO    F
#
#       Meter
# 0         3
# 1         5
# 2         2
# 3         3
# 4         2
# ...     ...
# 5660      4
# 5661      3
# 5662      5
# 5663      3
# 5664      4
#
# [5665 rows x 14 columns]

# %%
X.shape
# Out:
# (5665, 14)

# %%
feature_names = X.columns
feature_names
# Out:
# Index(['C', 'C#/Db', 'D', 'D#/Eb', 'E', 'F', 'F#/Gb', 'G', 'G#/Ab', 'A',
#        'A#/Bb', 'B', 'Bass', 'Meter'],
#       dtype='object')

# %%
class ele:
	def _init_(self):

		self.count = 0
		self.index = 0
		self.val = 0


def mycomp(a):
	return a.val

def mycomp2(a):
	return (a.count, -a.index)


def sortByFrequency(arr, n):
	element = [None for _ in range(n)]
	for i in range(n):
		element[i] = ele()
		element[i].index = i
		element[i].count = 0
		element[i].val = arr[i]
	element.sort(key=mycomp)
	element[0].count = 1

	for i in range(1, n):
		if (element[i].val == element[i - 1].val):
			element[i].count += element[i - 1].count + 1
			element[i - 1].count = -1
			element[i].index = element[i - 1].index
		else:
			element[i].count = 1

	element.sort(key=mycomp2)

	index = 0
	for i in range(n - 1, -1, -1):
		if (element[i].count != -1):
			for j in range(element[i].count):
				arr[index] = element[i].val
				index += 1

plt_array = Y.tolist()
sortByFrequency(plt_array, len(plt_array))

Y
# This code is contributed by phasing17 from geeksforgeeks.com
# Out:
# 0       F_M
# 1       C_M
# 2       C_M
# 3       F_M
# 4       F_M
#        ...
# 5660    G_m
# 5661    G_m
# 5662    C_M
# 5663    C_M
# 5664    F_M
# Name: Chord label, Length: 5665, dtype: object

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from pandas.core.arrays.categorical import Ordered
plt.figure(figsize=(40,10))
plt.xticks(rotation=45)
plt.margins(x=0.01)
freq, bins, _ = plt.hist(pd.Series(plt_array), edgecolor='white', bins=pd.Series(plt_array).unique().size)
bin_centers = np.diff(bins)*0.5 + bins[:-1]

for fr, x in zip(freq, bin_centers):
    height = int(fr)
    plt.annotate("{}".format(height),
               xy = (x, height),             
               xytext = (0,1),             
               textcoords = "offset points", 
               ha = 'center', va = 'bottom'
               )
plt.show()

# %%
len(np.unique(Y))
# Out:
# 102
